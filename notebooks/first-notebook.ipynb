# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dic = pd.read_csv('data_dictionary.csv')

# %%
data_dic.head(44)
# Out:
#                      Table            Field  \
# 0               world_cups             Year
# 1               world_cups     Host Country
# 2               world_cups           Winner
# 3               world_cups       Runners-Up
# 4               world_cups            Third
# 5               world_cups           Fourth
# 6               world_cups     Goals Scored
# 7               world_cups  Qualified Teams
# 8               world_cups   Matches Played
# 9         world_cup_groups            Group
# 10        world_cup_groups             Team
# 11        world_cup_groups     FIFA Ranking
# 12        world_cup_squads               ID
# 13        world_cup_squads             Team
# 14        world_cup_squads         Position
# 15        world_cup_squads           Player
# 16        world_cup_squads              Age
# 17        world_cup_squads             Caps
# 18        world_cup_squads            Goals
# 19        world_cup_squads         WC Goals
# ...

# %%
world_cups= pd.read_csv('world_cups.csv')
world_cups_matches = pd.read_csv('world_cup_matches.csv')
international_matches= pd.read_csv('international_matches.csv')
world_cup_squads=pd.read_csv('2022_world_cup_squads.csv',encoding= 'unicode_escape')
world_cup_matches=pd.read_csv('2022_world_cup_matches.csv')
world_cup_groups = pd.read_csv('2022_world_cup_groups.csv')

# %%
world_cups.shape
# Out:
# (22, 9)

# %%
world_cups.head()
# Out:
#    Year Host Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    Goals Scored  Qualified Teams  Matches Played
# 0          70.0               13              18
# 1          70.0               16              17
# 2          84.0               15              18
# 3          88.0               13              22
# 4         140.0               16              26

# %%
world_cups['Winner'].value_counts()
# Out:
# Brazil        5
# Italy         4
# Germany FR    3
# Uruguay       2
# Argentina     2
# France        2
# England       1
# Spain         1
# Germany       1
# Name: Winner, dtype: int64

# %%
world_cups['Runners-Up'].value_counts()
# Out:
# Argentina         3
# Germany FR        3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# Sweden            1
# Germany           1
# France            1
# Croatia           1
# Name: Runners-Up, dtype: int64

# %%
world_cups['Third'].value_counts()
# Out:
# Germany        3
# Brazil         2
# Sweden         2
# France         2
# Poland         2
# USA            1
# Austria        1
# Chile          1
# Portugal       1
# Germany FR     1
# Italy          1
# Croatia        1
# Turkey         1
# Netherlands    1
# Belgium        1
# Name: Third, dtype: int64

# %%
world_cups['Fourth'].value_counts()
# Out:
# Uruguay           3
# Yugoslavia        2
# Brazil            2
# England           2
# Austria           1
# Sweden            1
# Spain             1
# Germany FR        1
# Soviet Union      1
# Italy             1
# France            1
# Belgium           1
# Bulgaria          1
# Netherlands       1
# Korea Republic    1
# Portugal          1
# Name: Fourth, dtype: int64

# %%
world_cups['Host Country'].value_counts()
# Out:
# Mexico          2
# France          2
# Brazil          2
# Italy           2
# Germany         2
# Spain           1
# Russia          1
# South Africa    1
# Korea/Japan     1
# USA             1
# Uruguay         1
# Argentina       1
# England         1
# Chile           1
# Sweden          1
# Switzerland     1
# Qatar           1
# Name: Host Country, dtype: int64

# %% [markdown]
# ### **From World Cups Table :**
# + **Note(1) :** Brazil Is World Cup Winner **5** times
# + **Note(2) :** Brazil Is World Cup Runners-Up **2** times
# + **Note(3) :** Brazil Is World Cup Third **2** times
# + **Note(4) :** Brazil Is World Cup Fourth **2** times
# + **Note(5) :** Brazil Is World Cup Host Country **2** times

# %%
world_cups_matches.shape
# Out:
# (900, 10)

# %%
world_cups_matches.head()
# Out:
#    ID  Year        Date        Stage      Home Team  Home Goals  Away Goals  \
# 0   1  1930  1930-07-13  Group stage         France           4           1
# 1   2  1930  1930-07-13  Group stage  United States           3           0
# 2   3  1930  1930-07-14  Group stage     Yugoslavia           2           1
# 3   4  1930  1930-07-14  Group stage        Romania           3           1
# 4   5  1930  1930-07-15  Group stage      Argentina           1           0
#
#   Away Team Win Conditions  Host Team
# 0    Mexico            NaN      False
# 1   Belgium            NaN      False
# 2    Brazil            NaN      False
# 3      Peru            NaN      False
# 4    France            NaN      False

# %%
brazil_world_cups_matches = world_cups_matches[(world_cups_matches['Home Team']=='Brazil')|(world_cups_matches['Away Team']=='Brazil')]

# %%
brazil_world_cups_matches
# Out:
#       ID  Year        Date           Stage   Home Team  Home Goals  \
# 2      3  1930  1930-07-14     Group stage  Yugoslavia           2
# 11    12  1930  1930-07-20     Group stage      Brazil           4
# 23    24  1934  1934-05-27     Round of 16       Spain           3
# 40    41  1938  1938-06-05     Round of 16      Brazil           6
# 44    45  1938  1938-06-12  Quarter-finals      Brazil           1
# ..   ...   ...         ...             ...         ...         ...
# 846  847  2018  2018-06-17     Group stage      Brazil           1
# 859  860  2018  2018-06-22     Group stage      Brazil           2
# 878  879  2018  2018-06-27     Group stage      Serbia           0
# 888  889  2018  2018-07-02     Round of 16      Brazil           2
# 893  894  2018  2018-07-06  Quarter-finals      Brazil           1
#
#      Away Goals       Away Team Win Conditions  Host Team
# 2             1          Brazil            NaN      False
# ...

# %%
brazil_world_cups_matches['Stage'].value_counts()
# Out:
# Group stage           43
# Quarter-finals        14
# Round of 16           11
# First group stage      9
# Semi-finals            8
# Second group stage     8
# Final                  6
# Third place            4
# First round            3
# Final round            3
# Name: Stage, dtype: int64

# %%
brazil_home_goals = brazil_world_cups_matches[(brazil_world_cups_matches['Home Team']=='Brazil')][['Home Goals']].sum()
brazil_away_goals = brazil_world_cups_matches[(brazil_world_cups_matches['Away Team']=='Brazil')][['Away Goals']].sum()
print(brazil_home_goals)
print(brazil_away_goals)
# Out:
# Home Goals    176
# dtype: int64
# Away Goals    53
# dtype: int64

# %%
played_against_brazil = list(brazil_world_cups_matches['Away Team'].unique())+list(brazil_world_cups_matches['Home Team'].unique())

# %%
played_against_brazil.remove('Brazil')

# %%
played_against_brazil = list(set(played_against_brazil))

# %%
played_against_brazil
# Out:
# ['England',
#  'Switzerland',
#  'Algeria',
#  'Czechoslovakia',
#  'Peru',
#  'Colombia',
#  'Costa Rica',
#  'Hungary',
#  'Denmark',
#  'Uruguay',
#  'DR Congo',
#  'Australia',
#  'Germany',
#  'Northern Ireland',
#  'Yugoslavia',
#  'Turkey',
#  'Italy',
#  'Sweden',
#  'East Germany',
#  'Serbia',
#  'China',
#  'Ghana',
#  'Argentina',
#  'Russia',
#  'Bolivia',
#  'Netherlands',
#  'Romania',
#  'Scotland',
#  'North Korea',
#  'Spain',
#  'Portugal',
#  'Poland',
#  'France',
#  'Mexico',
#  'Belgium',
#  'New Zealand',
#  'Japan',
#  'United States',
#  'Bulgaria',
#  'Chile',
#  'Norway',
#  'Ivory Coast',
#  'Croatia',
#  'Morocco',
#  'Cameroon',
#  'Austria',
#  'Wales']

# %% [markdown]
# ### **From World Cups Matches Table :**
# + **Note(1) :** Brazil Played **109** matchs in World Cup Over-All
# + **Note(1) :** Brazil Played **43**  matchs in World Cup Group stage
# + **Note(1) :** Brazil Played **14**  matchs in World Cup Quarter-finals
# + **Note(1) :** Brazil Played **11**  matchs in World Cup Round of 16
# + **Note(1) :** Brazil Played **9**   matchs in World Cup First group stage
# + **Note(1) :** Brazil Played **8**   matchs in World Cup Second group stage
# + **Note(1) :** Brazil Played **8**   matchs in World Cup Semi-finals
# + **Note(1) :** Brazil Played **6**   matchs in World Cup Final
# + **Note(1) :** Brazil Played **4**   matchs in World Cup Third place
# + **Note(1) :** Brazil Played **3**   matchs in World Cup First round
# + **Note(1) :** Brazil Played **3**   matchs in World Cup Final round
# + **Note(1) :** Brazil Scored **176**   Goal in World Cup as Home Team
# + **Note(1) :** Brazil Scored **53**    Goal in World Cup as Away Team

# %%
international_matches.head()
# Out:
#    ID Tournament        Date Home Team  Home Goals  Away Goals Away Team  \
# 0   1   Friendly  1872-11-30  Scotland           0           0   England
# 1   2   Friendly  1873-03-08   England           4           2  Scotland
# 2   3   Friendly  1874-03-07  Scotland           2           1   England
# 3   4   Friendly  1875-03-06   England           2           2  Scotland
# 4   5   Friendly  1876-03-04  Scotland           3           0   England
#
#   Win Conditions  Home Stadium
# 0            NaN          True
# 1            NaN          True
# 2            NaN          True
# 3            NaN          True
# 4            NaN          True

# %%
brazil_international_matches = international_matches[(international_matches['Home Team']=='Brazil')|(international_matches['Away Team']=='Brazil')]

# %%
brazil_international_matches
# Out:
#           ID                    Tournament        Date    Home Team  \
# 320      321                      Friendly  1914-09-20    Argentina
# 321      322                     Copa Roca  1914-09-27    Argentina
# 333      334                  Copa America  1916-07-08       Brazil
# 334      335                  Copa America  1916-07-10    Argentina
# 336      337                  Copa America  1916-07-12       Brazil
# ...      ...                           ...         ...          ...
# 17628  17629  FIFA World Cup qualification  2022-03-29      Bolivia
# 17659  17660                      Friendly  2022-06-02  South Korea
# 17681  17682                      Friendly  2022-06-06        Japan
# 17734  17735                      Friendly  2022-09-23       Brazil
# 17755  17756                      Friendly  2022-09-27       Brazil
#
#        Home Goals  Away Goals Away Team Win Conditions  Home Stadium
# 320             3           0    Brazil            NaN          True
# ...

# %%
brazil_home_goals_in = brazil_international_matches[(brazil_international_matches['Home Team']=='Brazil')][['Home Goals']].sum()
brazil_away_goals_in = brazil_international_matches[(brazil_international_matches['Away Team']=='Brazil')][['Away Goals']].sum()
print(brazil_home_goals_in)
print(brazil_away_goals_in)
# Out:
# Home Goals    1285
# dtype: int64
# Away Goals    714
# dtype: int64

# %%
brazil_road_to_qatar = brazil_international_matches[brazil_international_matches['Tournament']=='FIFA World Cup qualification']

# %%
brazil_road_to_qatar.head()
# Out:
#         ID                    Tournament        Date Home Team  Home Goals  \
# 2070  2071  FIFA World Cup qualification  1954-02-28     Chile           0
# 2072  2073  FIFA World Cup qualification  1954-03-07  Paraguay           0
# 2074  2075  FIFA World Cup qualification  1954-03-14    Brazil           1
# 2078  2079  FIFA World Cup qualification  1954-03-21    Brazil           4
# 2356  2357  FIFA World Cup qualification  1957-04-13      Peru           1
#
#       Away Goals Away Team Win Conditions  Home Stadium
# 2070           2    Brazil            NaN          True
# 2072           1    Brazil            NaN          True
# 2074           0     Chile            NaN          True
# 2078           1  Paraguay            NaN          True
# 2356           1    Brazil            NaN          True

# %%
brazil_road_to_qatar.shape
# Out:
# (127, 9)

# %% [markdown]
# ### **From World Cups Matches Table :**
# + **Note(1) :** Brazil Played **109** matchs in World Cup Over-All
# + **Note(1) :** Brazil Played **43**  matchs in World Cup Group stage
# + **Note(1) :** Brazil Played **14**  matchs in World Cup Quarter-finals
# + **Note(1) :** Brazil Played **11**  matchs in World Cup Round of 16
# + **Note(1) :** Brazil Played **9**   matchs in World Cup First group stage
# + **Note(1) :** Brazil Played **8**   matchs in World Cup Second group stage
# + **Note(1) :** Brazil Played **8**   matchs in World Cup Semi-finals
# + **Note(1) :** Brazil Played **6**   matchs in World Cup Final
# + **Note(1) :** Brazil Played **4**   matchs in World Cup Third place
# + **Note(1) :** Brazil Played **3**   matchs in World Cup First round
# + **Note(1) :** Brazil Played **3**   matchs in World Cup Final round
# + **Note(1) :** Brazil Scored **176**   Goal in World Cup as Home Team
# + **Note(1) :** Brazil Scored **53**    Goal in World Cup as Away Team
